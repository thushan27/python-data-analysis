# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.24.2'

# %%
"input path of file into commas to access file needed"

data = pd.read_csv('/Users/thushan/downloads/weather_year.csv')

# %%
data
# Out:
#             EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0    10/03/2012                56                 40                24
# 1    11/03/2012                67                 49                30
# 2    12/03/2012                71                 62                53
# 3    13/03/2012                76                 63                50
# 4    14/03/2012                80                 62                44
# 5    15/03/2012                79                 69                58
# 6    16/03/2012                75                 64                52
# 7    17/03/2012                78                 62                46
# 8    18/03/2012                80                 70                59
# 9    19/03/2012                84                 72                59
# 10   20/03/2012                84                 71                58
# 11   21/03/2012                84                 71                57
# ...

# %%
"This removes spaces at the beginning of the column string and replaces any remaning spaces with underscore _"

new_columns = []
for col in data.columns:
    col = col.strip()
    new_columns.append(col.replace(" ", "_"))
data.columns = new_columns

# %%
"Break down above code into 1 line"

new_columns = [col.strip().replace(" ", "_") for col in data.columns]

# %%
"Column names are cleaner now"

data.head()
# Out:
#           EDT  Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# 0  10/03/2012                56                 40                24
# 1  11/03/2012                67                 49                30
# 2  12/03/2012                71                 62                53
# 3  13/03/2012                76                 63                50
# 4  14/03/2012                80                 62                44
#
#    Max_Dew_PointF  MeanDew_PointF  Min_DewpointF  Max_Humidity  Mean_Humidity  \
# 0              24              20             16            74             50
# 1              43              31             24            78             53
# 2              59              55             43            90             76
# 3              57              53             47            93             66
# 4              58              52             43            93             68
#
#    Min_Humidity  ...  Max_VisibilityMiles  Mean_VisibilityMiles  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
len(data)
# Out:
# 366

# %%
data2 = data[["EDT","Mean TemperatureF"]]

# %%
type(data2)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#        Max TemperatureF  Mean TemperatureF  Min TemperatureF  Max Dew PointF  \
# count        366.000000         366.000000        366.000000      366.000000
# mean          66.803279          55.683060         44.101093       49.549180
# std           20.361247          18.436506         17.301141       16.397178
# min           16.000000          11.000000          1.000000        0.000000
# 25%           51.000000          41.000000         30.000000       36.000000
# 50%           69.000000          59.000000         47.000000       54.500000
# 75%           84.000000          70.750000         57.750000       62.000000
# max          106.000000          89.000000         77.000000       77.000000
#
#        MeanDew PointF  Min DewpointF  Max Humidity   Mean Humidity  \
# count      366.000000     366.000000    366.000000      366.000000
# mean        44.057377      37.980874     90.027322       67.860656
# std         16.829996      17.479449      9.108438        9.945591
# ...

# %%
"Save data as new_weather.csv then load it again using pd.read_csv"

data.to_csv('new_weather.csv', sep =';', index = False)

# %%
new_data = pd.read_csv('new_weather.csv', sep =';')

# %%
new_data.head()
# Out:
#           EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  10/03/2012                56                 40                24
# 1  11/03/2012                67                 49                30
# 2  12/03/2012                71                 62                53
# 3  13/03/2012                76                 63                50
# 4  14/03/2012                80                 62                44
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              24              20             16            74
# 1              43              31             24            78
# 2              59              55             43            90
# 3              57              53             47            93
# 4              58              52             43            93
#
#     Mean Humidity   Min Humidity  ...   Max VisibilityMiles  \
# 0              50             26  ...                    10
# ...

# %%
"To get multiple columns from data set, pass column names as a list"

data[[' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn']]
# Out:
#       Mean Humidity   Min Humidity   Max Sea Level PressureIn
# 0                50             26                      30.53
# 1                53             28                      30.37
# 2                76             61                      30.13
# 3                66             38                      30.12
# 4                68             42                      30.15
# 5                69             48                      30.13
# 6                75             49                      30.14
# 7                78             56                      30.15
# 8                69             45                      30.14
# 9                66             42                      30.09
# 10               58             37                      30.09
# 11               58             32                      30.14
# 12               65             42                      30.11
# 13               79             61                      30.03
# ...

# %%
"Returns the number of times a value appears in the column - a numerical histogram"

data.Max_TemperatureF.value_counts()
# Out:
# 86     10
# 87      9
# 73      9
# 80      9
# 92      9
# 84      9
# 54      8
# 78      8
# 63      7
# 37      7
# 66      7
# 68      7
# 79      7
# 81      7
# 82      7
# 67      7
# 89      7
# 88      6
# 76      6
# 57      6
# 48      6
# 61      6
# 62      6
# 47      6
# 45      6
# 40      6
# 72      6
# 70      6
# 77      6
# 95      6
#        ..
# 59      3
# 101     3
# 74      3
# 58      3
# 90      3
# 64      3
# 65      3
# 85      3
# 93      3
# 97      3
# 34      2
# 35      2
# 30      2
# 49      2
# 41      2
# 29      2
# 26      2
# 28      1
# 25      1
# 27      1
# 18      1
# 24      1
# 106     1
# 38      1
# 42      1
# 104     1
# 96      1
# 99      1
# 100     1
# 16      1
# Name: Max_TemperatureF, Length: 83, dtype: int64
