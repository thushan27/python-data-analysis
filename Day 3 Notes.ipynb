# %%
import pandas as pd
link = 'https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'
html_content = pd.read_html(link)
new_nfl_frame = html_content[1]

# %%
import matplotlib.pyplot as plt

# %%
from pandas import DataFrame

# %%
new_nfl_frame
# Out:
#     Rank                     Team    GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys   898  512   380     6  0.573
# 1      2            Chicago Bears  1386  761   583    42  0.564
# 2      3        Green Bay Packers  1352  743   571    38  0.564
# 3      4  New England Patriots[b]   900  500   391     9  0.561
# 4      5           Miami Dolphins   816  452   360     4  0.556
# 5      6        Minnesota Vikings   886  478   397    11  0.546
# 6      7         Baltimore Ravens   368  200   167     1  0.545
# 7      8          New York Giants  1321  692   596    33  0.536
# 8      9           Denver Broncos   900  476   414    10  0.534
# 9     10      San Francisco 49ers  1018  532   472    14  0.529
# 10    11    Indianapolis Colts[c]   982  516   459     7  0.529
# 11    12      Pittsburgh Steelers  1208  628   558    22  0.529
# 12    13       Kansas City Chiefs   900  469   419    12  0.528
# 13    14          Oakland Raiders   900  466   423    11  0.524
# ...

# %%
"""
converts the column 'Team' to a string column then checks if the word 'Giants' is in any elements of 
that columnn. Only the 8th entry contains the word 'Giants'.
.contains checks to see if characters are in the string.
.endswith works backwards to see if characters are at the end of string
.startswith works forwards to see if characters are in the beginning of string
To find an integer, convert integer column to string then do .str.contains('number').
We use .str as opposed to .astype(str) because of the .contains method following it
"""
cond_str_contains = new_nfl_frame['Team'].str.contains('ts')

# %%
cond_str_contains
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: Team, dtype: bool

# %%
"""
filtered returns the row such that the condition we set above held
"""
filtered = new_nfl_frame[cond_str_contains]
filtered
# Out:
#     Rank                     Team    GP  Won  Lost  Tied   Pct.  \
# 3      4  New England Patriots[b]   900  500   391     9  0.561
# 7      8          New York Giants  1321  692   596    33  0.536
# 10    11    Indianapolis Colts[c]   982  516   459     7  0.529
# 11    12      Pittsburgh Steelers  1208  628   558    22  0.529
# 25    26       New Orleans Saints   802  362   435     5  0.454
# 26    27            New York Jets   900  401   491     8  0.450
#
#     First NFL Season   Division
# 3               1960   AFC East
# 7               1925   NFC East
# 10              1953  AFC South
# 11              1933  AFC North
# 25              1967  NFC South
# 26              1960   AFC East

# %%
new_nfl_frame.dtypes
# Out:
# Rank                  int64
# Team                 object
# GP                    int64
# Won                   int64
# Lost                  int64
# Tied                  int64
# Pct.                float64
# First NFL Season      int64
# Division             object
# dtype: object

# %%
new_nfl_frame['Won'].astype(str)
# Out:
# 0     512
# 1     761
# 2     743
# 3     500
# 4     452
# 5     478
# 6     200
# 7     692
# 8     476
# 9     532
# 10    516
# 11    628
# 12    469
# 13    466
# 14    344
# 15    600
# 16    447
# 17    568
# 18    190
# 19    577
# 20    469
# 21    431
# 22    415
# 23    559
# 24    357
# 25    362
# 26    401
# 27    121
# 28    170
# 29    358
# 30    553
# 31    260
# Name: Won, dtype: object

# %%
def f(x):
    return x*x

# %%
import json
from pprint import pprint

# %%
json_obj = """
{"zoo animal": "Lion", "food": ["meat","veggies","honey"],"fur":"golden","clothes":null,"diet":
[{"zoo_animal":"Gazelle","food":"grass","fur":"Brown"}]
}
"""

# %%
"""
We are converting JavaScript code into code Python can read
"""
data = json.loads(json_obj)

# %%
data
# Out:
# {'zoo animal': 'Lion',
#  'food': ['meat', 'veggies', 'honey'],
#  'fur': 'golden',
#  'clothes': None,
#  'diet': [{'zoo_animal': 'Gazelle', 'food': 'grass', 'fur': 'Brown'}]}

# %%
type(data)
# Out:
# dict

# %%
DataFrame(data['diet'])
# Out:
#     food    fur zoo_animal
# 0  grass  Brown    Gazelle

# %%
"""
converts code back to JSON
"""
json.dumps(data)
# Out:
# '{"zoo animal": "Lion", "food": ["meat", "veggies", "honey"], "fur": "golden", "clothes": null, "diet": [{"zoo_animal": "Gazelle", "food": "grass", "fur": "Brown"}]}'

# %%
"""
pretty print - prints out the dictionary in a more readable format
"""
pprint(data)
# Out:
# {'clothes': None,
#  'diet': [{'food': 'grass', 'fur': 'Brown', 'zoo_animal': 'Gazelle'}],
#  'food': ['meat', 'veggies', 'honey'],
#  'fur': 'golden',
#  'zoo animal': 'Lion'}

# %%
"""
plotly website - good for needing to use visualisations 
"""
# Out:
# '\nplotly website - good for needing to use visualisations \n'

# %%
"""
Opening an excel file, where .parse takes sheet 'Export'
df.to_excel(filename,'sheetname') takes a data frame df and adds it to an excel file sheet
"""
xlsfile = pd.ExcelFile('Planets.xlsx')
dFrameExcel = xlsfile.parse('Export')
dFrameExcel
# Out:
#     Planet       Mass  Diameter  DayLength  SunDistance  OrbitPeriod  \
# 0  MERCURY     0.3300      4879     4222.6         57.9         88.0
# 1    VENUS     4.8700     12104     2802.0        108.2        224.7
# 2    EARTH     5.9700     12756       24.0        149.6        365.2
# 3     MOON     0.0730      3475      708.7          NaN         27.3
# 4     MARS     0.6420      6792       24.7        227.9        687.0
# 5  JUPITER  1898.0000    142984        9.9        778.6       4331.0
# 6   SATURN   568.0000    120536       10.7       1433.5      10747.0
# 7   URANUS    86.8000     51118       17.2       2872.5      30589.0
# 8  NEPTUNE   102.0000     49528       16.1       4495.1      59800.0
# 9    PLUTO     0.0146      2370      153.3       5906.4      90560.0
#
#    OrbitVelocity  MeanTemperature  SurfacePressure  Moons Rings MagneticField  \
# 0           47.4              167          0.00000      0    No           Yes
# ...

# %%
dataList = [[1,2,3],['SF','LA','NYC'],[923702, 1937193,2037201]]
dataListF = pd.DataFrame(dataList)
df1 = dataListF.T
df1.columns = ['id','city','rank']

# %%
df1
# Out:
#   id city     rank
# 0  1   SF   923702
# 1  2   LA  1937193
# 2  3  NYC  2037201

# %%
DataFrame(dataList)
# Out:
#         0        1        2
# 0       1        2        3
# 1      SF       LA      NYC
# 2  923702  1937193  2037201

# %%
dataList = [[4,5,6],['London','Loughborough','Luton'],[30573, 204702,2032057201]]
dataListF = pd.DataFrame(dataList)
df2 = dataListF.T
df2.columns = ['id','city','rank']

# %%
dataList = [[4,5,6],['Bristol','Bath','Birmingham'],[2947239, 357935,35907350]]
dataListF = pd.DataFrame(dataList)
df3 = dataListF.T
df3.columns = ['id','city','rank']

# %%
df3
# Out:
#   id        city      rank
# 0  4     Bristol   2947239
# 1  5        Bath    357935
# 2  6  Birmingham  35907350

# %%
df2
# Out:
#   id          city        rank
# 0  4        London       30573
# 1  5  Loughborough      204702
# 2  6         Luton  2032057201

# %%
"""
.concat() takes one table and puts it under another (vertically), .merge() brings tables together horizontally
"""

tmp_df = pd.merge(df2, df3, how = 'outer', on = 'id', suffixes=('_left','_right'))

# %%
tmp_df
# Out:
#   id     city_left   rank_left  city_right rank_right
# 0  4        London       30573     Bristol    2947239
# 1  5  Loughborough      204702        Bath     357935
# 2  6         Luton  2032057201  Birmingham   35907350

# %%
"""
how to check if there are any missing values by using .isnull(), which returns the table with True meaning empty
element, False meaning non-empty element
"""
tmp_df.isnull()
# Out:
#       id  city_left  rank_left  city_right  rank_right
# 0  False      False      False       False       False
# 1  False      False      False       False       False
# 2  False      False      False       False       False

# %%
"""
.isnull().sum() returns the total number of missing entries for each column. Adding .sum() adds up the number of
missing entries from each column.
"""
tmp_df.isnull().sum()
# Out:
# id            0
# city_left     0
# rank_left     0
# city_right    0
# rank_right    0
# dtype: int64

# %%
"""
True if there are missing values, False is not.
"""
tmp_df.isnull().values.any()
# Out:
# False

# %%
"""
returns the % of missing values by summing the number of missing values, divided by number of entries by multiplying
number of rows and columns together.
"""
(tmp_df.isnull().sum().sum()/(tmp_df.shape[0]*tmp_df.shape[1]))*100
# Out:
# 0.0

# %%
tmp_df.size
# Out:
# 15

# %%
df = pd.read_csv('weather_year.csv')
df.columns
df.dtypes
# Out:
# EDT                            object
# Max TemperatureF                int64
# Mean TemperatureF               int64
# Min TemperatureF                int64
# Max Dew PointF                  int64
# MeanDew PointF                  int64
# Min DewpointF                   int64
# Max Humidity                    int64
#  Mean Humidity                  int64
#  Min Humidity                   int64
#  Max Sea Level PressureIn     float64
#  Mean Sea Level PressureIn    float64
#  Min Sea Level PressureIn     float64
#  Max VisibilityMiles            int64
#  Mean VisibilityMiles           int64
#  Min VisibilityMiles            int64
#  Max Wind SpeedMPH              int64
#  Mean Wind SpeedMPH             int64
#  Max Gust SpeedMPH            float64
# PrecipitationIn                object
#  CloudCover                     int64
#  Events                        object
#  WindDirDegrees                 int64
# dtype: object

# %%
"""
Converting the data type of EDT column from object to date 
"""
df['EDT'] = pd.to_datetime(df['EDT'], infer_datetime_format = 'True')

# %%
df.dtypes
df = df.set_index('EDT',drop=False)

# %%
df['Max Humidity'].plot(linewidth = 0.5)

# %%
dframe = DataFrame({'key1':['A']*2 + ['B']*3,'key2':[2,2,2,3,3]})

# %%
dframe
# Out:
#   key1  key2
# 0    A     2
# 1    A     2
# 2    B     2
# 3    B     3
# 4    B     3

# %%
"""
goes through each row and returns True for rows which have already been present
"""
dframe.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
dframe.drop_duplicates()
# Out:
#   key1  key2
# 0    A     2
# 2    B     2
# 3    B     3

# %%
dframe2 = DataFrame({'city':['Alma','Brian Head','Fox Park'],'altitude':[3150,3000,2762]})
state_map = {'Alma':'Colorado','Brian Head':'Utah','Fox Park':'Wyoming'}

# %%
dframe2
# Out:
#          city  altitude
# 0        Alma      3150
# 1  Brian Head      3000
# 2    Fox Park      2762

# %%
"""
.map() looks at the dictionary state_map and will recognise corresponding the exact key values in 'city' column 
of dframe2 and map it to the values in state_map. It will assign the header state to this column.
"""
dframe2['state'] = dframe2['city'].map(state_map)

# %%
dframe2
# Out:
#          city  altitude     state
# 0        Alma      3150  Colorado
# 1  Brian Head      3000      Utah
# 2    Fox Park      2762   Wyoming

# %%
years = [1990,2001,2014,2003,1986,1966,1971]
decade_bins = [1960,1970,1980,1990,2000,2010,2020]

# %%
decade_cat = pd.cut(years,decade_bins)

# %%
decade_cat.categories
# Out:
# IntervalIndex([(1960, 1970], (1970, 1980], (1980, 1990], (1990, 2000], (2000, 2010], (2010, 2020]],
#               closed='right',
#               dtype='interval[int64]')

# %%
pd.value_counts(decade_cat)
# Out:
# (2000, 2010]    2
# (1980, 1990]    2
# (2010, 2020]    1
# (1970, 1980]    1
# (1960, 1970]    1
# (1990, 2000]    0
# dtype: int64

# %%
pd.cut(years, 2, precision = 1)
# Out:
# [(1966.0, 1990.0], (1990.0, 2014.0], (1990.0, 2014.0], (1990.0, 2014.0], (1966.0, 1990.0], (1966.0, 1990.0], (1966.0, 1990.0]]
# Categories (2, interval[float64]): [(1966.0, 1990.0] < (1990.0, 2014.0]]

# %%
pd.value_counts(decade_cat).hist()

# %%
new_nfl_frame
# Out:
#     Rank                     Team    GP  Won  Lost  Tied   Pct.  \
# 0      1           Dallas Cowboys   898  512   380     6  0.573
# 1      2            Chicago Bears  1386  761   583    42  0.564
# 2      3        Green Bay Packers  1352  743   571    38  0.564
# 3      4  New England Patriots[b]   900  500   391     9  0.561
# 4      5           Miami Dolphins   816  452   360     4  0.556
# 5      6        Minnesota Vikings   886  478   397    11  0.546
# 6      7         Baltimore Ravens   368  200   167     1  0.545
# 7      8          New York Giants  1321  692   596    33  0.536
# 8      9           Denver Broncos   900  476   414    10  0.534
# 9     10      San Francisco 49ers  1018  532   472    14  0.529
# 10    11    Indianapolis Colts[c]   982  516   459     7  0.529
# 11    12      Pittsburgh Steelers  1208  628   558    22  0.529
# 12    13       Kansas City Chiefs   900  469   419    12  0.528
# 13    14          Oakland Raiders   900  466   423    11  0.524
# ...

# %%
pd.pivot_table(new_nfl_frame, index = ['GP','Won'], aggfunc = 'mean')
# Out:
#           First NFL Season  Lost   Pct.  Rank  Tied
# GP   Won
# 272  121              2002   151  0.445    28     0
# 368  200              1996   167  0.545     7     1
# 384  170              1995   214  0.443    29     0
#      190              1995   193  0.496    19     1
# 676  260              1976   415  0.385    32     1
#      344              1976   331  0.510    15     1
# 788  357              1968   427  0.456    25     4
# 802  362              1967   435  0.454    26     5
# 816  358              1966   452  0.442    30     6
#      452              1966   360  0.556     5     4
# 886  478              1961   397  0.546     6    11
# 898  512              1960   380  0.573     1     6
# 900  401              1960   491  0.450    27     8
#      415              1960   477  0.466    23     8
#      431              1960   463  0.482    22     6
#      447              1960   442  0.503    17    11
#      466              1960   423  0.524    14    11
# ...

# %%
raw_data = {
    "city":["Tripoli","Sydney","Tripoli","Rome","Rome","Tripoli","Rome","Sydney","Rome"],
    "rank":["1st","2nd","1st","2nd","1st","2nd","1st","2nd","1st"],
    "score1": [44,45,47,23,46,77,86,14,56],
    "score2": [66,45,88,45,67,24,85,64,25]
    }

# %%
dFrame3 = pd.DataFrame(raw_data, columns = ["city","rank","score1","score2"])
dFrame3
# Out:
#       city rank  score1  score2
# 0  Tripoli  1st      44      66
# 1   Sydney  2nd      45      45
# 2  Tripoli  1st      47      88
# 3     Rome  2nd      23      45
# 4     Rome  1st      46      67
# 5  Tripoli  2nd      77      24
# 6     Rome  1st      86      85
# 7   Sydney  2nd      14      64
# 8     Rome  1st      56      25

# %%
pd.pivot_table(dFrame3,index = ["city","rank"],aggfunc = "sum")
# Out:
#               score1  score2
# city    rank
# Rome    1st      188     177
#         2nd       23      45
# Sydney  2nd       59     109
# Tripoli 1st       91     154
#         2nd       77      24

# %%
new_dFrame3 = dFrame3.pivot_table(index = ["city","rank"], aggfunc = "count")
new_dFrame3
# Out:
#               score1  score2
# city    rank
# Rome    1st        3       3
#         2nd        1       1
# Sydney  2nd        2       2
# Tripoli 1st        2       2
#         2nd        1       1

# %%
new_dFrame3.index
# Out:
# MultiIndex(levels=[['Rome', 'Sydney', 'Tripoli'], ['1st', '2nd']],
#            codes=[[0, 0, 1, 2, 2], [0, 1, 1, 0, 1]],
#            names=['city', 'rank'])

# %%
new_dFrame3.loc[('Rome','1st'),:]
# Out:
# score1    3
# score2    3
# Name: (Rome, 1st), dtype: int64

# %%
group1 = new_nfl_frame['Won'].groupby(new_nfl_frame['Division'])

# %%
group1.mean()
# Out:
# Division
# AFC East     442.00
# AFC North    413.50
# AFC South    309.50
# AFC West     464.50
# NFC East     595.25
# NFC North    635.25
# NFC South    292.50
# NFC West     499.25
# Name: Won, dtype: float64

# %%
list(group1)
# Out:
# [('AFC East', 3     500
#   4     452
#   22    415
#   26    401
#   Name: Won, dtype: int64), ('AFC North', 6     200
#   11    628
#   20    469
#   24    357
#   Name: Won, dtype: int64), ('AFC South', 10    516
#   21    431
#   27    121
#   28    170
#   Name: Won, dtype: int64), ('AFC West', 8     476
#   12    469
#   13    466
#   16    447
#   Name: Won, dtype: int64), ('NFC East', 0     512
#   7     692
#   15    600
#   19    577
#   Name: Won, dtype: int64), ('NFC North', 1     761
#   2     743
#   5     478
#   23    559
#   Name: Won, dtype: int64), ('NFC South', 18    190
#   25    362
#   29    358
#   31    260
#   Name: Won, dtype: int64), ('NFC West', 9     532
#   14    344
#   17    568
#   30    553
#   Name: Won, dtype: int64)]

# %%
groups = new_nfl_frame.groupby(new_nfl_frame['Division'])
for name, group in groups:
    print(name)
    print(group)
# Out:
# AFC East
#     Rank                     Team   GP  Won  Lost  Tied   Pct.  \
# 3      4  New England Patriots[b]  900  500   391     9  0.561
# 4      5           Miami Dolphins  816  452   360     4  0.556
# 22    23            Buffalo Bills  900  415   477     8  0.466
# 26    27            New York Jets  900  401   491     8  0.450
#
#     First NFL Season  Division
# 3               1960  AFC East
# 4               1966  AFC East
# 22              1960  AFC East
# 26              1960  AFC East
# AFC North
#     Rank                 Team    GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 6      7     Baltimore Ravens   368  200   167     1  0.545              1996
# 11    12  Pittsburgh Steelers  1208  628   558    22  0.529              1933
# 20    21     Cleveland Browns   970  469   490    11  0.489              1950
# 24    25   Cincinnati Bengals   788  357   427     4  0.456              1968
#
#      Division
# 6   AFC North
# 11  AFC North
# 20  AFC North
# ...

# %%
"""
scatter plot of wins against losses
"""
new_nfl_frame.plot(kind = "scatter",x = "Won",y = "Lost")

# %%
"""
Intro to Machine Learning
"""
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = new_nfl_frame[['Lost','Won','GP','Tied']]
y = new_nfl_frame['Pct.']

# %%
X_train = x[:-10]
X_test = x[-10:]
y_train = y[:-10]
y_test = y[-10:]

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)

# %%
y_pred
# Out:
# array([0.47459423, 0.44193321, 0.4736403 , 0.4715766 , 0.46100787,
#        0.49955415, 0.49176936, 0.46077881, 0.3881939 , 0.43483981])

# %%
print(regr.coef_)
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# [-0.00036642  0.00060403 -0.00012766 -0.00036527]
# 0.001076211672012847
# -1.2355407490763524

# %%
plt.scatter(X_train['Tied'], y_train)
